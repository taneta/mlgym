# %%
import pandas as pd
import numpy as np
import random 
import pickle 
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load Data with pandas, and parse the first column into datetime

train=pd.read_csv('data/train.csv', parse_dates = ['Dates'])
test=pd.read_csv('data/test.csv', parse_dates = ['Dates'])

# %% [markdown]
# ## Take a look at data

# %%
print (train.shape)

train.head(10)
# Out:
# (878049, 9)
#                 Dates        Category                        Descript  \
# 0 2015-05-13 23:53:00        WARRANTS                  WARRANT ARREST
# 1 2015-05-13 23:53:00  OTHER OFFENSES        TRAFFIC VIOLATION ARREST
# 2 2015-05-13 23:33:00  OTHER OFFENSES        TRAFFIC VIOLATION ARREST
# 3 2015-05-13 23:30:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 4 2015-05-13 23:30:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 5 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO
# 6 2015-05-13 23:30:00   VEHICLE THEFT               STOLEN AUTOMOBILE
# 7 2015-05-13 23:30:00   VEHICLE THEFT               STOLEN AUTOMOBILE
# 8 2015-05-13 23:00:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 9 2015-05-13 23:00:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                        Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED             OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED             OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED      VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE       1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE      100 Block of BRODERICK ST
# 5  Wednesday  INGLESIDE            NONE            0 Block of TEDDY AV
# 6  Wednesday  INGLESIDE            NONE            AVALON AV / PERU AV
# 7  Wednesday    BAYVIEW            NONE       KIRKWOOD AV / DONAHUE ST
# 8  Wednesday   RICHMOND            NONE           600 Block of 47TH AV
# 9  Wednesday    CENTRAL            NONE  JEFFERSON ST / LEAVENWORTH ST
#
#             X          Y
# 0 -122.425892  37.774599
# 1 -122.425892  37.774599
# 2 -122.424363  37.800414
# 3 -122.426995  37.800873
# 4 -122.438738  37.771541
# 5 -122.403252  37.713431
# 6 -122.423327  37.725138
# 7 -122.371274  37.727564
# 8 -122.508194  37.776601
# 9 -122.419088  37.807802

# %%
train.describe()
# Out:
#                    X              Y
# count  878049.000000  878049.000000
# mean     -122.422616      37.771020
# std         0.030354       0.456893
# min      -122.513642      37.707879
# 25%      -122.432952      37.752427
# 50%      -122.416420      37.775421
# 75%      -122.406959      37.784369
# max      -120.500000      90.000000

# %%
# How many of test addreses we saw in train data

repet_crime_addr = np.in1d(test['Address'], train['Address']).astype(int)
print("Addresses already seen: ", float(sum(repet_crime_addr))/len(repet_crime_addr)*100)
# Out:
# ('Addresses already seen: ', 99.64116969857349)

# %% [markdown]
# ## Tf-idf for addresses

# %%
# Devide text information into separate files by category of crime

# Factor levels
categories = list(train['Category'].unique())

addr_cat = {}

# Subset by category
for cat in categories:
    df_category_mask = train['Category'] == cat
    df_cat = train[df_category_mask] # select by mask
    
    df_cat_addr = list(df_cat['Address']) # select only addresses
    addr_cat[cat] = df_cat_addr

# %%
# Check length
print(len(addr_cat.values()))
print(sum([len(x) for x in addr_cat.values()]))
print(len(train))
# Out:
# 39
# 878049
# 878049

# %%
# For Addresses
addr_docs = [' '.join(x) for x in addr_cat.values()] # imulation of sentences from adresses

# define vectorizer parameters
# max_df: the maximum frequency within the documents a given feature can have to be used
# min_df: could be an integer (e.g. 5) and the term would have to be in at least 5 of the documents to be considered. 
# ngram_range: this just means I'll look at unigrams, bigrams, trigrams and 4grams.
tfidf_vectorizer_addr = TfidfVectorizer(max_df=0.8, analyzer='word', lowercase=False, stop_words=['Block', 'of', '/'],
                                        tokenizer=None, norm=None, smooth_idf=False,
                                 min_df=1, use_idf=True, ngram_range=(1,4))


# %time tfidf_matrix_addr = tfidf_vectorizer_addr.fit_transform(addr_docs) #fit the vectorizer to addr_docs

print(tfidf_matrix_addr.shape)
# Out:
# CPU times: user 20.2 s, sys: 540 ms, total: 20.7 s
# Wall time: 20.7 s
# (39, 1118159)

# %%
# Check results visually

random.seed(120)
numbr = random.sample(range(len(train)), 10)

for n in numbr:
    
    response = tfidf_vectorizer_addr.transform(train.iloc[[n]]['Address'])
    cosine = cosine_similarity(response, tfidf_matrix_addr)

    print train.iloc[[n]]
    sort_rez = sorted(zip(addr_cat.keys(), cosine[0]), key=lambda x: x[1], reverse=True)

    for x in sort_rez:
        if x[1] > 0:
            print x[0], x[1]
# Out:
#                      Dates Category Descript DayOfWeek PdDistrict Resolution  \
# 452140 2008-12-28 02:00:00  ASSAULT  BATTERY    Sunday   SOUTHERN       NONE
#
#                        Address           X          Y
# 452140  400 Block of JESSIE ST -122.408534  37.782033
# LIQUOR LAWS 0.0944143307599
# WARRANTS 0.0642728644903
# DRUNKENNESS 0.0458374439827
# DRUG/NARCOTIC 0.0448385089308
# OTHER OFFENSES 0.0302629807004
# ROBBERY 0.0277717684953
# WEAPON LAWS 0.0262275157172
# BRIBERY 0.022374887698
# ASSAULT 0.022349958614
# VANDALISM 0.0202910404107
# ARSON 0.0186545930168
# SEX OFFENSES FORCIBLE 0.0185487713129
# SUSPICIOUS OCC 0.0183105367922
# RECOVERED VEHICLE 0.0172797790989
# FRAUD 0.0161277673937
# NON-CRIMINAL 0.0153184954207
# LARCENY/THEFT 0.014520811146
# VEHICLE THEFT 0.0140520500996
# STOLEN PROPERTY 0.0130202072633
# BURGLARY 0.0129986623453
# DISORDERLY CONDUCT 0.0122605516695
# TRESPASS 0.0117751000725
# KIDNAPPING 0.00906060162456
# LOITERING 0.00663372630327
# FORGERY/COUNTERFEITING 0.00645474086174
# EMBEZZLEMENT 0.00420738749667
# MISSING PERSON 0.0024874356062
# SECONDARY CODES 0.0021727608918
#                      Dates       Category                      Descript  \
# 165642 2013-03-06 08:40:00  LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#         DayOfWeek PdDistrict Resolution             Address           X  \
# 165642  Wednesday   NORTHERN       NONE  EDDY ST / GOUGH ST -122.424109
#
#                 Y
# 165642  37.782476
# LARCENY/THEFT 0.103620138999
# VEHICLE THEFT 0.102760815083
# VANDALISM 0.0950535474343
# STOLEN PROPERTY 0.0538058957283
# ROBBERY 0.0535137081763
# BURGLARY 0.0512270322919
# NON-CRIMINAL 0.0423471395727
# DRIVING UNDER THE INFLUENCE 0.0415911717793
# OTHER OFFENSES 0.0400951117531
# KIDNAPPING 0.0371213716617
# SUSPICIOUS OCC 0.0362307801297
# ASSAULT 0.0350120718456
# WARRANTS 0.0335351262553
# WEAPON LAWS 0.0331643154603
# TRESPASS 0.0305953625338
# SEX OFFENSES FORCIBLE 0.029722355539
# FRAUD 0.0291551593742
# RECOVERED VEHICLE 0.0278186637794
# SECONDARY CODES 0.0270004787306
# ARSON 0.0214966624074
# FORGERY/COUNTERFEITING 0.0203768201449
# SUICIDE 0.0192225857999
# DRUG/NARCOTIC 0.0175249402447
# LOITERING 0.0120704261528
# BAD CHECKS 0.0108901836575
# DRUNKENNESS 0.0100481629978
# DISORDERLY CONDUCT 0.00725716829246
# MISSING PERSON 0.00552301544711
# LIQUOR LAWS 0.00378464188598
# RUNAWAY 0.00107098546741
# PROSTITUTION 0.000966295574684
#                      Dates                Category  \
# 836710 2003-07-23 02:28:00  FORGERY/COUNTERFEITING
#
#                            Descript  DayOfWeek PdDistrict  \
# 836710  MONEY, CHANGING FACE AMOUNT  Wednesday  INGLESIDE
#
#                           Resolution                   Address           X  \
# 836710  PROSECUTED BY OUTSIDE AGENCY  4100 Block of MISSION ST -122.429615
#
#                Y
# 836710  37.73027
# SEX OFFENSES NON FORCIBLE 0.0228061966484
# FORGERY/COUNTERFEITING 0.0131141938333
# STOLEN PROPERTY 0.00845127343706
# ROBBERY 0.0081952271598
# RECOVERED VEHICLE 0.00747740980073
# LOITERING 0.00730532339287
# WEAPON LAWS 0.00704840080166
# SECONDARY CODES 0.00538364420686
# LIQUOR LAWS 0.00455098480879
# BURGLARY 0.00434571367807
# VEHICLE THEFT 0.00430309769588
# ASSAULT 0.00405168905088
# DRIVING UNDER THE INFLUENCE 0.00387854449715
# WARRANTS 0.00383873877446
# SUSPICIOUS OCC 0.00363655441858
# DRUNKENNESS 0.00270882301008
# OTHER OFFENSES 0.00259843161186
# LARCENY/THEFT 0.00214365678872
# DISORDERLY CONDUCT 0.00210206632468
# TRESPASS 0.00194508131812
# NON-CRIMINAL 0.00173588541641
# DRUG/NARCOTIC 0.00130713247234
# FRAUD 0.00112948580463
# VANDALISM 0.0010034112028
# MISSING PERSON 0.000243072270366
#                      Dates       Category                 Descript DayOfWeek  \
# 557797 2007-06-29 00:30:00  LARCENY/THEFT  PETTY THEFT OF PROPERTY    Friday
#
#         PdDistrict Resolution              Address           X          Y
# 557797  TENDERLOIN       NONE  TURK ST / TAYLOR ST -122.410769  37.783215
# DRUG/NARCOTIC 0.114448148453
# WARRANTS 0.0763879843209
# OTHER OFFENSES 0.0589840697258
# ROBBERY 0.0458432605384
# WEAPON LAWS 0.0377137692286
# ASSAULT 0.0366014324357
# DRUNKENNESS 0.0342586811561
# SUSPICIOUS OCC 0.0261799292458
# DRIVING UNDER THE INFLUENCE 0.0188662437215
# LIQUOR LAWS 0.0177097338733
# SECONDARY CODES 0.0174582920287
# BRIBERY 0.0155164385689
# NON-CRIMINAL 0.014776642471
# KIDNAPPING 0.0145605188048
# FRAUD 0.0109882222498
# STOLEN PROPERTY 0.0109624480378
# SEX OFFENSES FORCIBLE 0.0095976421211
# TRESPASS 0.00756910294214
# RECOVERED VEHICLE 0.00727441109983
# LARCENY/THEFT 0.00571234757746
# VANDALISM 0.00536893681399
# FORGERY/COUNTERFEITING 0.0042527220757
# DISORDERLY CONDUCT 0.00408999774316
# VEHICLE THEFT 0.00322021235415
# MISSING PERSON 0.00189178624014
# BURGLARY 0.000603962156089
#                      Dates                Category  \
# 517752 2008-01-25 06:48:00  FORGERY/COUNTERFEITING
#
#                                    Descript DayOfWeek  PdDistrict  \
# 517752  FORGERY, DRIVERS LICENSE OR ID-CARD    Friday  TENDERLOIN
#
#             Resolution                      Address           X          Y
# 517752  ARREST, BOOKED  200 Block of GOLDEN GATE AV -122.414263  37.781757
# FAMILY OFFENSES 0.0629691533276
# DISORDERLY CONDUCT 0.0576058432393
# ASSAULT 0.0513791160194
# TRESPASS 0.0440335450448
# SECONDARY CODES 0.0384875165258
# DRUG/NARCOTIC 0.0360158469844
# WARRANTS 0.0353432992124
# SUSPICIOUS OCC 0.0311971466697
# WEAPON LAWS 0.0272939404894
# KIDNAPPING 0.0237772276414
# SEX OFFENSES FORCIBLE 0.0235093259305
# OTHER OFFENSES 0.0206401248259
# NON-CRIMINAL 0.0196488414042
# BAD CHECKS 0.0160246421474
# FORGERY/COUNTERFEITING 0.0138893321378
# BURGLARY 0.0118351928509
# LARCENY/THEFT 0.0116602806652
# DRUNKENNESS 0.00968264862612
# VANDALISM 0.00896669703785
# LOITERING 0.00870425756254
# ROBBERY 0.0073234302042
# FRAUD 0.00672888442308
# STOLEN PROPERTY 0.00671310100608
# RECOVERED VEHICLE 0.00445464884346
# MISSING PERSON 0.00434429155384
# VEHICLE THEFT 0.00394393856553
#                      Dates        Category          Descript DayOfWeek  \
# 825738 2003-09-16 00:09:00  OTHER OFFENSES  RESISTING ARREST   Tuesday
#
#        PdDistrict      Resolution                   Address           X  \
# 825738    BAYVIEW  ARREST, BOOKED  MENDELL ST / KIRKWOOD AV -122.388093
#
#                 Y
# 825738  37.737108
# WEAPON LAWS 0.0580639804386
# GAMBLING 0.0318172986034
# RECOVERED VEHICLE 0.0313024757161
# OTHER OFFENSES 0.0306026489534
# ASSAULT 0.029755525378
# SECONDARY CODES 0.0291588492566
# SUSPICIOUS OCC 0.0258366102539
# WARRANTS 0.023774527719
# VANDALISM 0.0230988263934
# ROBBERY 0.0205766778184
# ARSON 0.0170936113387
# DISORDERLY CONDUCT 0.0170161849817
# VEHICLE THEFT 0.0164686862341
# BURGLARY 0.0139627752473
# SEX OFFENSES FORCIBLE 0.0121248251014
# NON-CRIMINAL 0.0111066159057
# DRUG/NARCOTIC 0.0103791381853
# EMBEZZLEMENT 0.0102500150404
# DRIVING UNDER THE INFLUENCE 0.0101094106143
# DRUNKENNESS 0.00955742668228
# FAMILY OFFENSES 0.00779425124961
# SUICIDE 0.00692743192299
# LIQUOR LAWS 0.00671188057747
# FORGERY/COUNTERFEITING 0.0055425686351
# LARCENY/THEFT 0.00527710692439
# STOLEN PROPERTY 0.00519337575825
# TRESPASS 0.00506984662351
# FRAUD 0.00481801119547
# MISSING PERSON 0.00471136441535
# KIDNAPPING 0.00367889824745
# RUNAWAY 0.0014245059587
#                     Dates       Category              Descript DayOfWeek  \
# 80111 2014-04-19 00:17:00  DRUG/NARCOTIC  POSSESSION OF HEROIN  Saturday
#
#       PdDistrict      Resolution              Address           X          Y
# 80111   NORTHERN  ARREST, BOOKED  MYRTLE ST / POLK ST -122.419641  37.785433
# WARRANTS 0.106713472493
# PROSTITUTION 0.0753491670028
# DISORDERLY CONDUCT 0.0655894135685
# STOLEN PROPERTY 0.0620836901839
# OTHER OFFENSES 0.0587666342116
# LARCENY/THEFT 0.0570449706523
# DRUG/NARCOTIC 0.0515996495225
# ROBBERY 0.0503911387308
# DRUNKENNESS 0.0501834120282
# ASSAULT 0.0449337106929
# NON-CRIMINAL 0.0412284498233
# SUSPICIOUS OCC 0.0404206361309
# VANDALISM 0.0403433782677
# DRIVING UNDER THE INFLUENCE 0.0399199155244
# WEAPON LAWS 0.0370862423875
# SEX OFFENSES FORCIBLE 0.0370270261568
# VEHICLE THEFT 0.0332717224784
# LIQUOR LAWS 0.0327237014572
# LOITERING 0.0275405275366
# FRAUD 0.0240615359149
# ARSON 0.0239774183227
# KIDNAPPING 0.019618304475
# RECOVERED VEHICLE 0.0166834076436
# SECONDARY CODES 0.0151874094881
# EXTORTION 0.0144861341733
# FORGERY/COUNTERFEITING 0.013378187538
# BURGLARY 0.00627297861735
# BRIBERY 0.00627188262228
# TRESPASS 0.00548712829651
# MISSING PERSON 0.00414338077286
#                      Dates Category                      Descript DayOfWeek  \
# 696163 2005-07-01 00:01:00    FRAUD  CREDIT CARD, THEFT BY USE OF    Friday
#
#        PdDistrict Resolution                     Address          X          Y
# 696163   NORTHERN       NONE  VANNESS AV / CALIFORNIA ST -122.42233  37.790369
# VEHICLE THEFT 0.0192431868345
# NON-CRIMINAL 0.017628605633
# FRAUD 0.0171407044645
# SUSPICIOUS OCC 0.0170095875039
# DRIVING UNDER THE INFLUENCE 0.0159397951194
# OTHER OFFENSES 0.0148688012697
# FORGERY/COUNTERFEITING 0.0138295506648
# DISORDERLY CONDUCT 0.0126221689551
# LARCENY/THEFT 0.0118718754485
# VANDALISM 0.00998427736327
# ROBBERY 0.00971415848753
# DRUNKENNESS 0.00857714669218
# PROSTITUTION 0.00843586150258
# WEAPON LAWS 0.00835477542427
# ASSAULT 0.00713630296175
# STOLEN PROPERTY 0.00623936197428
# SEX OFFENSES FORCIBLE 0.00623140074346
# WARRANTS 0.00474631115862
# KIDNAPPING 0.00315120549266
# RECOVERED VEHICLE 0.00236150557417
# DRUG/NARCOTIC 0.00196221769014
# BURGLARY 0.00196065355479
# MISSING PERSON 0.00138180167471
# TRESPASS 0.00122858596689
# SECONDARY CODES 0.00113350354759
#                      Dates Category                     Descript DayOfWeek  \
# 195934 2012-10-05 21:25:00  ASSAULT  MAYHEM WITH A DEADLY WEAPON    Friday
#
#        PdDistrict      Resolution                Address           X  \
# 195934       PARK  ARREST, BOOKED  1800 Block of EDDY ST -122.438098
#
#                 Y
# 195934  37.780639
# WEAPON LAWS 0.0249342607725
# SECONDARY CODES 0.0195333908539
# SEX OFFENSES FORCIBLE 0.0178973688185
# KIDNAPPING 0.0162911872698
# ASSAULT 0.0122855675298
# BURGLARY 0.0121634876456
# SUSPICIOUS OCC 0.00950000594114
# VANDALISM 0.00709928884485
# ARSON 0.00630793978487
# ROBBERY 0.00594692253418
# MISSING PERSON 0.00555619214911
# LIQUOR LAWS 0.00495367979149
# WARRANTS 0.00417841049592
# NON-CRIMINAL 0.00330659989443
# FORGERY/COUNTERFEITING 0.00317213476022
# OTHER OFFENSES 0.00309772154756
# DRUNKENNESS 0.00294851386404
# VEHICLE THEFT 0.00216178076673
# TRESPASS 0.00211719230522
# LARCENY/THEFT 0.00152174267869
# DRUG/NARCOTIC 0.00124494510242
# FRAUD 0.00122942862705
#                      Dates       Category                Descript DayOfWeek  \
# 220543 2012-06-01 14:57:00  LARCENY/THEFT  PETTY THEFT WITH PRIOR    Friday
#
#        PdDistrict Resolution                 Address           X          Y
# 220543   SOUTHERN       NONE  800 Block of MARKET ST -122.406521  37.785063

# %%
# Get tf-idf for train

response_train = tfidf_vectorizer_addr.transform(train['Address'])
cosine_train = cosine_similarity(response_train, tfidf_matrix_addr)

col_names_addr = ['tfidf_' + x for x in addr_cat.keys()]

tfidf_train = pd.DataFrame(cosine_train, columns=col_names_addr)
print tfidf_train.shape
# Out:
# (878049, 39)

# %%
# Get tf-idf for test

response_test = tfidf_vectorizer_addr.transform(test['Address'])
cosine_test = cosine_similarity(response_test, tfidf_matrix_addr)

tfidf_test = pd.DataFrame(cosine_test, columns=col_names_addr)
print tfidf_test.shape
# Out:
# (884262, 39)

# %%
# Save features to pkl 

tfidf_train.to_pickle("data/tfidf_train.pkl")
tfidf_test.to_pickle("data/tfidf_test.pkl")

# %%
# Save tf-df matrix to file

#store the content
with open("data/tfidf_matrix.pkl", 'wb') as handle:
                    pickle.dump(tfidf_matrix_addr, handle)
        
#load the content
tfidf = pickle.load(open("data/tfidf_matrix.pkl", "rb" ) )

# %%
# Ideas
# Convert cosine similarity to class probability
